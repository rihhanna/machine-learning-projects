# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sklearn.linear_model import LinearRegression

# %%
df =pd.read_csv('../data/houses.csv')
df.head()
# Out:
#    size  bedrooms  bathrooms   price
# 0  1000         2          1  120000
# 1  1200         2          2  140000
# 2  1500         3          2  180000
# 3  1800         3          3  220000
# 4  2000         4          3  250000

# %%
print(df.shape)
print(df.describe())
# Out:
# (9, 4)
#               size  bedrooms  bathrooms          price
# count     9.000000  9.000000   9.000000       9.000000
# mean   2000.000000  3.777778   3.222222  252222.222222
# std     694.622199  1.394433   1.394433   96924.942324
# min    1000.000000  2.000000   1.000000  120000.000000
# 25%    1500.000000  3.000000   2.000000  180000.000000
# 50%    2000.000000  4.000000   3.000000  250000.000000
# 75%    2500.000000  5.000000   4.000000  320000.000000
# max    3000.000000  6.000000   5.000000  400000.000000

# %%
x=df[["size","bedrooms","bathrooms"]]
y=df["price"]

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
new_house=[[2100,4,3]]

pridiction=model.predict(new_house)

print("predicted price: $",round(pridiction[0],2))
# Out:
# predicted price: $ 264000.0
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("intercept:",model.intercept_)
print("coefficients:",model.coef_)
# Out:
# intercept: -20000.000000000087
# coefficients: [  100. 14000.  6000.]

# %%
plt.scatter(df["size"],df["price"])
plt.xlabel("House Size ")
plt.ylabel("price")
plt.title("House Size vs Price")
plt.show()
